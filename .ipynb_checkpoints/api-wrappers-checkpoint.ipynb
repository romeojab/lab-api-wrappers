# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from random import randint
from time import sleep
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", 200, "display.max_columns", 200)

# %%
secrets_file = open("C:\\Users\\Romeo\\IronHack\\secrets.txt","r")
string = secrets_file.read()
string.split('\n')
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['secret']))

# %%
our_playlist = sp.user_playlist_tracks("spotify", "3LgwHwHUnheGm88n8pDdA7")
print(len(our_playlist["items"]))
our_playlist["total"]
# Out:
# 11
# 11

# %%
def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
# %%time
our_tracks = get_playlist_tracks("3LgwHwHUnheGm88n8pDdA7")
print(len(our_tracks))
our_tracks[0]['track'].keys()
# Out:
# 11
# Wall time: 82.3 ms
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
print(our_tracks[0]['track']['artists'][0]['name'])
print(our_tracks[0]['track']['name'])
# Out:
# Bon Jovi
# Livin' On A Prayer

# %%
song_uri = our_playlist["items"][0]["track"]["uri"]
song_uri
# Out:
# 'spotify:track:37ZJ0p5Jm13JPevGcx4SkF'

# %%
length = len(our_tracks)
rang = range(length-1)
our_list_uri = []
our_songs = []
our_artist = []
for i in rang:
    our_list_uri.append(our_playlist["items"][i]["track"]["uri"])
    our_songs.append(our_tracks[i]['track']['name'])
    our_artist.append(our_tracks[i]['track']['artists'][0]['name'])
    
our_df = pd.DataFrame()
our_df['artist'] = our_artist
our_df['songs'] = our_songs
our_df['uri'] = our_list_uri
#print(df.shape)
our_df
# Out:
#                 artist                       songs  \
# 0             Bon Jovi          Livin' On A Prayer
# 1           Rose Royce           Wishing on a Star
# 2                 Muse                   Supremacy
# 3            Whigfield  Saturday Night - Radio Mix
# 4               Eminem         The Real Slim Shady
# 5  Echo & the Bunnymen                  The Cutter
# 6            Die Ärzte               Schunder-Song
# 7              Dr. Dre                Still D.R.E.
# 8           Supertramp                     Dreamer
# 9                   KK                Feel My Love
#
#                                     uri
# 0  spotify:track:37ZJ0p5Jm13JPevGcx4SkF
# 1  spotify:track:0u2CGItUO2jYEiFaXD7n5S
# 2  spotify:track:40pPI2TbaYSZlKfV44HRjn
# 3  spotify:track:59VRFpPnC8pOhIH2WCWXF9
# 4  spotify:track:3yfqSUWxFvZELEM4PmlwIR
# 5  spotify:track:1uquUeoieXGKOyuHfjWWdS
# 6  spotify:track:2OLPgRjanLolNsJLkI3cms
# 7  spotify:track:503OTo2dSqe7qk76rgsbep
# ...

# %%
print(our_songs)
print(our_artist)
our_list_uri
# Out:
# ["Livin' On A Prayer", 'Wishing on a Star', 'Supremacy', 'Saturday Night - Radio Mix', 'The Real Slim Shady', 'The Cutter', 'Schunder-Song', 'Still D.R.E.', 'Dreamer', 'Feel My Love']
# ['Bon Jovi', 'Rose Royce', 'Muse', 'Whigfield', 'Eminem', 'Echo & the Bunnymen', 'Die Ärzte', 'Dr. Dre', 'Supertramp', 'KK']
# ['spotify:track:37ZJ0p5Jm13JPevGcx4SkF',
#  'spotify:track:0u2CGItUO2jYEiFaXD7n5S',
#  'spotify:track:40pPI2TbaYSZlKfV44HRjn',
#  'spotify:track:59VRFpPnC8pOhIH2WCWXF9',
#  'spotify:track:3yfqSUWxFvZELEM4PmlwIR',
#  'spotify:track:1uquUeoieXGKOyuHfjWWdS',
#  'spotify:track:2OLPgRjanLolNsJLkI3cms',
#  'spotify:track:503OTo2dSqe7qk76rgsbep',
#  'spotify:track:5z4ljpMLi1LTF8UG9P53fH',
#  'spotify:track:4EjO3ELtQkbOBox5adad6a']

# %%
our_list_features = sp.audio_features(our_list_uri)

# %%
our_list_features[0].keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %%
print(len(our_list_features))
print(len(our_list_features[0]))#['danceability']
#our_list_features
# Out:
# 10
# 18

# %%
length = len(our_list_features)
rang = range(length)
list_danceability = []
list_energy = []
list_key = []
list_loudness = []
list_mode = []
list_speechiness = []
list_acousticness = []
list_instrumentalness = []
list_liveness = []
list_valence = []
list_tempo = []
list_type = []
list_id = []
#list_uri = []
list_track_href = []
list_analysis_url = []
list_duration_ms = []
list_time_signature = []

for i in rang:
    list_danceability.append(our_list_features[i]['danceability'])
    list_energy.append(our_list_features[i]['energy'])
    list_key.append(our_list_features[i]['key'])
    list_loudness.append(our_list_features[i]['loudness'])
    list_mode.append(our_list_features[i]['mode'])
    list_speechiness.append(our_list_features[i]['speechiness'])
    list_acousticness.append(our_list_features[i]['acousticness'])
    list_instrumentalness.append(our_list_features[i]['instrumentalness'])
    list_liveness.append(our_list_features[i]['liveness'])
    list_valence.append(our_list_features[i]['valence'])
    list_tempo.append(our_list_features[i]['tempo'])
    list_type.append(our_list_features[i]['type'])
    list_id.append(our_list_features[i]['id'])
#    list_uri.append(our_list_features[i]['uri'])
    list_track_href.append(our_list_features[i]['track_href'])
    list_analysis_url.append(our_list_features[i]['analysis_url'])
    list_duration_ms.append(our_list_features[i]['duration_ms'])
    list_time_signature.append(our_list_features[i]['time_signature'])

# %%
list_energy
# Out:
# [0.887, 0.422, 0.679, 0.784, 0.661, 0.955, 0.951, 0.775, 0.414, 0.697]

# %%
our_df['danceability'] = list_danceability
our_df['energy'] = list_energy
our_df['key'] = list_key
our_df['loudness'] = list_loudness
our_df['mode'] = list_mode
our_df['speechiness'] = list_speechiness
our_df['acousticness'] = list_acousticness
our_df['instrumentalness'] = list_instrumentalness
our_df['liveness'] = list_liveness
our_df['valence'] = list_valence
our_df['tempo'] = list_tempo
our_df['type'] = list_type
our_df['id'] = list_id
our_df['track_href'] = list_track_href
our_df['analysis_url'] = list_analysis_url
our_df['duration_ms'] = list_duration_ms
our_df['time_signature'] = list_time_signature

print(our_df.shape)
our_df
# Out:
# (10, 20)
#                 artist                       songs  \
# 0             Bon Jovi          Livin' On A Prayer
# 1           Rose Royce           Wishing on a Star
# 2                 Muse                   Supremacy
# 3            Whigfield  Saturday Night - Radio Mix
# 4               Eminem         The Real Slim Shady
# 5  Echo & the Bunnymen                  The Cutter
# 6            Die Ärzte               Schunder-Song
# 7              Dr. Dre                Still D.R.E.
# 8           Supertramp                     Dreamer
# 9                   KK                Feel My Love
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:37ZJ0p5Jm13JPevGcx4SkF         0.532   0.887    0    -3.757
# 1  spotify:track:0u2CGItUO2jYEiFaXD7n5S         0.333   0.422    5   -15.171
# 2  spotify:track:40pPI2TbaYSZlKfV44HRjn         0.256   0.679    9    -4.495
# 3  spotify:track:59VRFpPnC8pOhIH2WCWXF9         0.728   0.784   11   -11.776
# ...

# %%
def features_func(list_features):
    length = len(list_features)
    rang = range(length)
    list_danceability = []
    list_energy = []
    list_key = []
    list_loudness = []
    list_mode = []
    list_speechiness = []
    list_acousticness = []
    list_instrumentalness = []
    list_liveness = []
    list_valence = []
    list_tempo = []
    list_type = []
    list_id = []
    list_track_href = []
    list_analysis_url = []
    list_duration_ms = []
    list_time_signature = []

    for i in rang:
        list_danceability.append(list_features[i]['danceability'])
        list_energy.append(list_features[i]['energy'])
        list_key.append(list_features[i]['key'])
        list_loudness.append(list_features[i]['loudness'])
        list_mode.append(list_features[i]['mode'])
        list_speechiness.append(list_features[i]['speechiness'])
        list_acousticness.append(list_features[i]['acousticness'])
        list_instrumentalness.append(list_features[i]['instrumentalness'])
        list_liveness.append(list_features[i]['liveness'])
        list_valence.append(list_features[i]['valence'])
        list_tempo.append(list_features[i]['tempo'])
        list_type.append(list_features[i]['type'])
        list_id.append(list_features[i]['id'])
        list_track_href.append(list_features[i]['track_href'])
        list_analysis_url.append(list_features[i]['analysis_url'])
        list_duration_ms.append(list_features[i]['duration_ms'])
        list_time_signature.append(list_features[i]['time_signature'])

    df['danceability'] = list_danceability
    df['energy'] = list_energy
    df['key'] = list_key
    df['loudness'] = list_loudness
    df['mode'] = list_mode
    df['speechiness'] = list_speechiness
    df['acousticness'] = list_acousticness
    df['instrumentalness'] = list_instrumentalness
    df['liveness'] = list_liveness
    df['valence'] = list_valence
    df['tempo'] = list_tempo
    df['type'] = list_type
    df['id'] = list_id
    df['track_href'] = list_track_href
    df['analysis_url'] = list_analysis_url
    df['duration_ms'] = list_duration_ms
    df['time_signature'] = list_time_signature

#print(df.shape)
    return df

# %%
# putting it all in functions
def super_song_func(tracks):
    length = len(tracks)
    rang = range(length-1)
    list_uri = []
    songs = []
    artist = []
    for i in rang:
        list_uri.append(our_playlist["items"][i]["track"]["uri"])
        songs.append(tracks[i]['track']['name'])
        artist.append(tracks[i]['track']['artists'][0]['name'])
    df = pd.DataFrame()
    df['artist'] = artist
    df['songs'] = songs
    df['uri'] = list_uri
    
    list_features = sp.audio_features(list_uri)


    length = len(list_features)
    rang = range(length)
    list_danceability = []
    list_energy = []
    list_key = []
    list_loudness = []
    list_mode = []
    list_speechiness = []
    list_acousticness = []
    list_instrumentalness = []
    list_liveness = []
    list_valence = []
    list_tempo = []
    list_type = []
    list_id = []
    list_track_href = []
    list_analysis_url = []
    list_duration_ms = []
    list_time_signature = []

    for i in rang:
        list_danceability.append(list_features[i]['danceability'])
        list_energy.append(list_features[i]['energy'])
        list_key.append(list_features[i]['key'])
        list_loudness.append(list_features[i]['loudness'])
        list_mode.append(list_features[i]['mode'])
        list_speechiness.append(list_features[i]['speechiness'])
        list_acousticness.append(list_features[i]['acousticness'])
        list_instrumentalness.append(list_features[i]['instrumentalness'])
        list_liveness.append(list_features[i]['liveness'])
        list_valence.append(list_features[i]['valence'])
        list_tempo.append(list_features[i]['tempo'])
        list_type.append(list_features[i]['type'])
        list_id.append(list_features[i]['id'])
        list_track_href.append(list_features[i]['track_href'])
        list_analysis_url.append(list_features[i]['analysis_url'])
        list_duration_ms.append(list_features[i]['duration_ms'])
        list_time_signature.append(list_features[i]['time_signature'])

    df['danceability'] = list_danceability
    df['energy'] = list_energy
    df['key'] = list_key
    df['loudness'] = list_loudness
    df['mode'] = list_mode
    df['speechiness'] = list_speechiness
    df['acousticness'] = list_acousticness
    df['instrumentalness'] = list_instrumentalness
    df['liveness'] = list_liveness
    df['valence'] = list_valence
    df['tempo'] = list_tempo
    df['type'] = list_type
    df['id'] = list_id
    df['track_href'] = list_track_href
    df['analysis_url'] = list_analysis_url
    df['duration_ms'] = list_duration_ms
    df['time_signature'] = list_time_signature

#print(df.shape)
    return df

# %%
# song_func(our_tracks)
# list_features = sp.audio_features(list_uri)
# features_fun(list_features)
super_song_func(our_tracks)
# Out:
#                 artist                       songs  \
# 0             Bon Jovi          Livin' On A Prayer
# 1           Rose Royce           Wishing on a Star
# 2                 Muse                   Supremacy
# 3            Whigfield  Saturday Night - Radio Mix
# 4               Eminem         The Real Slim Shady
# 5  Echo & the Bunnymen                  The Cutter
# 6            Die Ärzte               Schunder-Song
# 7              Dr. Dre                Still D.R.E.
# 8           Supertramp                     Dreamer
# 9                   KK                Feel My Love
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:37ZJ0p5Jm13JPevGcx4SkF         0.532   0.887    0    -3.757
# 1  spotify:track:0u2CGItUO2jYEiFaXD7n5S         0.333   0.422    5   -15.171
# 2  spotify:track:40pPI2TbaYSZlKfV44HRjn         0.256   0.679    9    -4.495
# 3  spotify:track:59VRFpPnC8pOhIH2WCWXF9         0.728   0.784   11   -11.776
# ...

# %% [markdown]
# ### Now to gather data for the longer playlist

# %%
# %%time
# playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY") #6yPiKpy7evrwvZodByKvM9
# print(len(playlist["items"]))
# playlist["total"]

# %%
# %%time
all_tracks = get_playlist_tracks("4rnleEAOdmFAbRcNCgZMpY")
len(all_tracks)
# Out:
# Wall time: 1min 57s
# 5295

# %%
# song_uri = playlist["items"][0]["track"]["uri"]
# song_uri

# %%
len(all_tracks)
# Out:
# 5295

# %%
#playlist["items"][99]["track"]["uri"]
all_tracks[1]["track"]["uri"]
# Out:
# 'spotify:track:2V4bv1fNWfTcyRJKmej6Sj'

# %%
def list_func(tracks):
    length = len(all_tracks)
    rang = range(length)
    list_uri = []
    for i in rang:
        list_uri.append(all_tracks[i]["track"]["uri"])
    return list_uri

list_func(all_tracks)
len(list_uri)
# Out:
# 5296

# %%
len(all_tracks)
# Out:
# 5295

# %%
def song_func(tracks):
    length = len(tracks)
    rang = range(length)
    list_uri = []
    songs = []
    artist = []
    for i in rang:
        list_uri.append(tracks[i]["track"]["uri"])
        songs.append(tracks[i]['track']['name'])
        artist.append(tracks[i]['track']['artists'][0]['name'])

    df = pd.DataFrame()
    df['artist'] = artist
    df['songs'] = songs
    df['uri'] = list_uri
    #print(df.shape)
    return df 

df = song_func(all_tracks)
print(df.shape)
df
# Out:
# (5295, 3)
#                   artist                                 songs  \
# 0                 Hozier                     Take Me To Church
# 1            Mike Posner           Cooler Than Me - Single Mix
# 2     Tyler, The Creator      See You Again (feat. Kali Uchis)
# 3               Bastille                               Pompeii
# 4                Shakira    Hips Don't Lie (feat. Wyclef Jean)
# ...                  ...                                   ...
# 5290              MARINA                       Hermit the Frog
# 5291      Olivia Rodrigo                               deja vu
# 5292                 BIA                     WHOLE LOTTA MONEY
# 5293            Ashnikko  Slumber Party (feat. Princess Nokia)
# 5294          Kali Uchis                             telepatía
#
#                                        uri
# 0     spotify:track:7dS5EaCoMnN7DzlpT6aRn2
# 1     spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 2     spotify:track:7KA4W4McWYRpgf0fWsJZWB
# ...

# %%
len(list_uri)-1
# Out:
# 5295

# %%
# source for solution: https://datagy.io/python-split-list-into-chunks/

lst = list_uri
chunked_list = []
chunk_size = 50
for i in range(0, len(lst), chunk_size):
    chunked_list.append(lst[i:i+chunk_size])
#chunked_list[0]
len(chunked_list)
# Out:
# 106

# %%
# a duplicate has been created...
list1 = chunked_list[0]
list2 = chunked_list[105]

common_uri = [uri for uri in list1 if uri in list2]
common_uri
# Out:
# ['spotify:track:7dS5EaCoMnN7DzlpT6aRn2']

# %%
# %%time
length = len(chunked_list)
rang = range(length)
list_features = []
for i in rang:
    list_features.append(sp.audio_features(chunked_list[i]))
    sleep(randint(1,3))
#    print(i)
# Out:
# Wall time: 3min 48s

# %%
# list_features = features_list
# list_features
#list_features[0].keys()
print(len(list_features))
print(len(list_features[0]))#['danceability']
list_features
display(list_features[0][0])
display(list_features[105][45])
# Out:
# 106
# 50
# {'danceability': 0.566,
#  'energy': 0.664,
#  'key': 4,
#  'loudness': -5.303,
#  'mode': 0,
#  'speechiness': 0.0464,
#  'acousticness': 0.634,
#  'instrumentalness': 0,
#  'liveness': 0.116,
#  'valence': 0.437,
#  'tempo': 128.945,
#  'type': 'audio_features',
#  'id': '7dS5EaCoMnN7DzlpT6aRn2',
#  'uri': 'spotify:track:7dS5EaCoMnN7DzlpT6aRn2',
#  'track_href': 'https://api.spotify.com/v1/tracks/7dS5EaCoMnN7DzlpT6aRn2',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dS5EaCoMnN7DzlpT6aRn2',
#  'duration_ms': 241688,
#  'time_signature': 4}
# {'danceability': 0.566,
#  'energy': 0.664,
#  'key': 4,
#  'loudness': -5.303,
#  'mode': 0,
#  'speechiness': 0.0464,
#  'acousticness': 0.634,
#  'instrumentalness': 0,
#  'liveness': 0.116,
#  'valence': 0.437,
#  'tempo': 128.945,
#  'type': 'audio_features',
#  'id': '7dS5EaCoMnN7DzlpT6aRn2',
#  'uri': 'spotify:track:7dS5EaCoMnN7DzlpT6aRn2',
# ...

# %%
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
list_features2 = flatten(list_features)
#list_features2

# %%
list_features2[0].keys()
print(len(list_features2))
print(len(list_features2[0]))#['danceability']
#list_features2
# list_features2[0]
# Out:
# 5296
# 18

# %%
display(list_features2[0])
display(list_features2[5295])
# Out:
# {'danceability': 0.566,
#  'energy': 0.664,
#  'key': 4,
#  'loudness': -5.303,
#  'mode': 0,
#  'speechiness': 0.0464,
#  'acousticness': 0.634,
#  'instrumentalness': 0,
#  'liveness': 0.116,
#  'valence': 0.437,
#  'tempo': 128.945,
#  'type': 'audio_features',
#  'id': '7dS5EaCoMnN7DzlpT6aRn2',
#  'uri': 'spotify:track:7dS5EaCoMnN7DzlpT6aRn2',
#  'track_href': 'https://api.spotify.com/v1/tracks/7dS5EaCoMnN7DzlpT6aRn2',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dS5EaCoMnN7DzlpT6aRn2',
#  'duration_ms': 241688,
#  'time_signature': 4}
# {'danceability': 0.566,
#  'energy': 0.664,
#  'key': 4,
#  'loudness': -5.303,
#  'mode': 0,
#  'speechiness': 0.0464,
#  'acousticness': 0.634,
#  'instrumentalness': 0,
#  'liveness': 0.116,
#  'valence': 0.437,
#  'tempo': 128.945,
#  'type': 'audio_features',
#  'id': '7dS5EaCoMnN7DzlpT6aRn2',
#  'uri': 'spotify:track:7dS5EaCoMnN7DzlpT6aRn2',
#  'track_href': 'https://api.spotify.com/v1/tracks/7dS5EaCoMnN7DzlpT6aRn2',
# ...

# %%
length = len(list_features2)
rang = range(length)
list_uri = []
list_danceability = []
list_energy = []
list_key = []
list_loudness = []
list_mode = []
list_speechiness = []
list_acousticness = []
list_instrumentalness = []
list_liveness = []
list_valence = []
list_tempo = []
list_type = []
list_id = []
list_track_href = []
list_analysis_url = []
list_duration_ms = []
list_time_signature = []

for i in rang:
    list_uri.append(list_features2[i]['uri'])
    list_danceability.append(list_features2[i]['danceability'])
    list_energy.append(list_features2[i]['energy'])
    list_key.append(list_features2[i]['key'])
    list_loudness.append(list_features2[i]['loudness'])
    list_mode.append(list_features2[i]['mode'])
    list_speechiness.append(list_features2[i]['speechiness'])
    list_acousticness.append(list_features2[i]['acousticness'])
    list_instrumentalness.append(list_features2[i]['instrumentalness'])
    list_liveness.append(list_features2[i]['liveness'])
    list_valence.append(list_features2[i]['valence'])
    list_tempo.append(list_features2[i]['tempo'])
    list_type.append(list_features2[i]['type'])
    list_id.append(list_features2[i]['id'])
    list_track_href.append(list_features2[i]['track_href'])
    list_analysis_url.append(list_features2[i]['analysis_url'])
    list_duration_ms.append(list_features2[i]['duration_ms'])
    list_time_signature.append(list_features2[i]['time_signature'])

#df_features = pd.DataFrame()
df_features['feature_uri'] = list_uri
df_features['danceability'] = list_danceability
df_features['energy'] = list_energy
df_features['key'] = list_key
df_features['loudness'] = list_loudness
df_features['mode'] = list_mode
df_features['speechiness'] = list_speechiness
df_features['acousticness'] = list_acousticness
df_features['instrumentalness'] = list_instrumentalness
df_features['liveness'] = list_liveness
df_features['valence'] = list_valence
df_features['tempo'] = list_tempo
df_features['type'] = list_type
df_features['id'] = list_id
df_features['track_href'] = list_track_href
df_features['analysis_url'] = list_analysis_url
df_features['duration_ms'] = list_duration_ms
df_features['time_signature'] = list_time_signature

print(df_features.shape)
df_features

# features_df_features = features_func2(list_features2)
# features_df_features
# Out:
# (5296, 18)
#                                feature_uri  danceability  energy  key  \
# 0     spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4
# 1     spotify:track:2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7
# 2     spotify:track:7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6
# 3     spotify:track:3gbBpTdY8lnQwqxNCcf795         0.679   0.715    9
# 4     spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10
# ...                                    ...           ...     ...  ...
# 5291  spotify:track:61KpQadow081I2AsbeLcsb         0.439   0.610    9
# 5292  spotify:track:5yorXJWdBan1Vlh116ZtQ7         0.897   0.371    1
# 5293  spotify:track:11ZulcYY4lowvcQm4oe3VJ         0.964   0.398   11
# 5294  spotify:track:6tDDoYIxWvMLTdKpjFkc1B         0.653   0.524   11
# 5295  spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
len(df_features.track_href.value_counts(dropna=False))
# Out:
# 5290

# %%
print(len(list_features2))
df.shape
# Out:
# 5296
# (5295, 3)

# %%
df_features.duplicated(keep='last').tail(5296)
# index row 5295 is duplicated
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5291    False
# 5292    False
# 5293    False
# 5294    False
# 5295    False
# Length: 5296, dtype: bool

# %%
display(df_features.head(1))
df_features.tail(1)
# Out:
#                             feature_uri  danceability  energy  key  loudness  \
# 0  spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4    -5.303
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0464         0.634               0.0     0.116    0.437
#
#      tempo            type                      id  \
# 0  128.945  audio_features  7dS5EaCoMnN7DzlpT6aRn2
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7dS5EaCoMnN7...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7dS5...       241688
#
#    time_signature
# 0               4
#                                feature_uri  danceability  energy  key  \
# 5295  spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
display(df.head(1))
df.tail(1)
# Out:
#    artist              songs                                   uri
# 0  Hozier  Take Me To Church  spotify:track:7dS5EaCoMnN7DzlpT6aRn2
#           artist      songs                                   uri
# 5294  Kali Uchis  telepatía  spotify:track:6tDDoYIxWvMLTdKpjFkc1B

# %%
df_features_clean = df_features.iloc[:-1 , :]
df_features_clean.shape
# Out:
# (5295, 18)

# %%
df_features_clean.duplicated(keep='last').tail(5296)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5290    False
# 5291    False
# 5292    False
# 5293    False
# 5294    False
# Length: 5295, dtype: bool

# %%
length = len(chunked_list)
rang = range(length)
    
len(chunked_list[0]+chunked_list[1])

bk_list_uri=[]
for i in rang:    
    bk_list_uri.append(chunked_list[i])
#bk_list_uri

# %%
# bringing back to OG list
bk_list_uri2 = flatten(bk_list_uri)
len(bk_list_uri2)
# Out:
# 5296

# %%
print(df.shape)
df
# Out:
# (5295, 3)
#                   artist                                 songs  \
# 0                 Hozier                     Take Me To Church
# 1            Mike Posner           Cooler Than Me - Single Mix
# 2     Tyler, The Creator      See You Again (feat. Kali Uchis)
# 3               Bastille                               Pompeii
# 4                Shakira    Hips Don't Lie (feat. Wyclef Jean)
# ...                  ...                                   ...
# 5290              MARINA                       Hermit the Frog
# 5291      Olivia Rodrigo                               deja vu
# 5292                 BIA                     WHOLE LOTTA MONEY
# 5293            Ashnikko  Slumber Party (feat. Princess Nokia)
# 5294          Kali Uchis                             telepatía
#
#                                        uri
# 0     spotify:track:7dS5EaCoMnN7DzlpT6aRn2
# 1     spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 2     spotify:track:7KA4W4McWYRpgf0fWsJZWB
# ...

# %%
print(df_features_clean.shape)
df_features_clean
# Out:
# (5295, 18)
#                                feature_uri  danceability  energy  key  \
# 0     spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4
# 1     spotify:track:2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7
# 2     spotify:track:7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6
# 3     spotify:track:3gbBpTdY8lnQwqxNCcf795         0.679   0.715    9
# 4     spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10
# ...                                    ...           ...     ...  ...
# 5290  spotify:track:4Zcz6saEkOII3PlXd9gN3o         0.609   0.679    0
# 5291  spotify:track:61KpQadow081I2AsbeLcsb         0.439   0.610    9
# 5292  spotify:track:5yorXJWdBan1Vlh116ZtQ7         0.897   0.371    1
# 5293  spotify:track:11ZulcYY4lowvcQm4oe3VJ         0.964   0.398   11
# 5294  spotify:track:6tDDoYIxWvMLTdKpjFkc1B         0.653   0.524   11
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
full_df = df.join(df_features_clean)#pd.concat(['df','df_features_clean'], axis = 1)
print(full_df.shape)
full_df
# Out:
# (5295, 21)
#                   artist                                 songs  \
# 0                 Hozier                     Take Me To Church
# 1            Mike Posner           Cooler Than Me - Single Mix
# 2     Tyler, The Creator      See You Again (feat. Kali Uchis)
# 3               Bastille                               Pompeii
# 4                Shakira    Hips Don't Lie (feat. Wyclef Jean)
# ...                  ...                                   ...
# 5290              MARINA                       Hermit the Frog
# 5291      Olivia Rodrigo                               deja vu
# 5292                 BIA                     WHOLE LOTTA MONEY
# 5293            Ashnikko  Slumber Party (feat. Princess Nokia)
# 5294          Kali Uchis                             telepatía
#
#                                        uri  \
# 0     spotify:track:7dS5EaCoMnN7DzlpT6aRn2
# 1     spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 2     spotify:track:7KA4W4McWYRpgf0fWsJZWB
# ...

# %%
full_df['validation'] = np.where(full_df['uri']==full_df['feature_uri'],True,False)
full_df
# Out:
#                   artist                                 songs  \
# 0                 Hozier                     Take Me To Church
# 1            Mike Posner           Cooler Than Me - Single Mix
# 2     Tyler, The Creator      See You Again (feat. Kali Uchis)
# 3               Bastille                               Pompeii
# 4                Shakira    Hips Don't Lie (feat. Wyclef Jean)
# ...                  ...                                   ...
# 5290              MARINA                       Hermit the Frog
# 5291      Olivia Rodrigo                               deja vu
# 5292                 BIA                     WHOLE LOTTA MONEY
# 5293            Ashnikko  Slumber Party (feat. Princess Nokia)
# 5294          Kali Uchis                             telepatía
#
#                                        uri  \
# 0     spotify:track:7dS5EaCoMnN7DzlpT6aRn2
# 1     spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 2     spotify:track:7KA4W4McWYRpgf0fWsJZWB
# ...

# %%
full_df.loc[full_df['validation'] == False]
# Out:
# Empty DataFrame
# Columns: [artist, songs, uri, feature_uri, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, track_href, analysis_url, duration_ms, time_signature, validation]
# Index: []

# %%
full_df = full_df.drop(['feature_uri','validation'], axis=1)
full_df.to_csv('spotify_songs_and_features.csv', index=False)
